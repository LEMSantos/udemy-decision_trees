# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data and getting a quick summary from then.

# %%
df = pd.read_csv('data/Movie_regression.csv', header=0)
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ## Missing value imputation

# %%
df['Time_taken'].fillna(value=df['Time_taken'].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ## Dummy variable creation

# %%
df = pd.get_dummies(df, columns=['3D_available', 'Genre'], drop_first=True)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %% [markdown]
# ## Data and target split

# %%
data = df.drop('Collection', axis=1)
target = df['Collection']

# %%
data.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
target.head()
# Out:
# 0    48000
# 1    43200
# 2    69400
# 3    66800
# 4    72400
# Name: Collection, dtype: int64

# %% [markdown]
# ## Test-train split

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data, train_target, test_target = train_test_split(
    data,
    target,
    test_size=0.2,
    random_state=1,
)

# %% [markdown]
# ## Training a Regression Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regression_tree = DecisionTreeRegressor(max_depth=3)

# %%
regression_tree.fit(train_data, train_target)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# ## Predict values using trained model

# %%
train_target_predicted = regression_tree.predict(train_data)
test_target_predicted = regression_tree.predict(test_data)

# %% [markdown]
# ## Evaluating model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(test_target, test_target_predicted)
# Out:
# 104098131.49178298

# %%
r2_score(train_target, train_target_predicted)
# Out:
# 0.8367303215166144

# %%
r2_score(test_target, test_target_predicted)
# Out:
# 0.736666798408077

# %% [markdown]
# ## Plotting decision tree

# %%
from sklearn.tree import export_graphviz

# %%
dot_data = export_graphviz(regression_tree, out_file=None)

# %%
from IPython.display import Image

# %%
import pydotplus

# %%
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [markdown]
# ## Controlling tree growth

# %%
def get_tree_image(tree):
    tree.fit(train_data, train_target)

    dot_data = export_graphviz(
        tree,
        out_file=None,
        feature_names=train_data.columns,
        filled=True,
    )

    graph = pydotplus.graph_from_dot_data(dot_data)
    return Image(graph.create_png())

# %% [markdown]
# ### Maximum number of levels in tree

# %%
regression_tree_1 = DecisionTreeRegressor(max_depth=3)
get_tree_image(regression_tree_1)

# %% [markdown]
# ### Minimum observations at internal node

# %%
regression_tree_2 = DecisionTreeRegressor(min_samples_split=40)
get_tree_image(regression_tree_2)

# %% [markdown]
# ### Minimum observations at leaf node

# %%
regression_tree_3 = DecisionTreeRegressor(min_samples_leaf=25)
get_tree_image(regression_tree_3)
